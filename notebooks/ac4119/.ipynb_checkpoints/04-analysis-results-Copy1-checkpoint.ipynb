# %%
import json
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/chuamelia/anaconda/envs/py35/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
base = '/Users/chuamelia/Google Drive/Spring 2020/Machine Learning/fake-review-detection-project/data/processed/dev/'

def readJsonFile(fname, base=base):
    with open(base + fname + '.json', 'r') as f:
        data = json.load(f)
    return data

# %%
fname = 'sgd_attempts_ac4119_202005117'
all_attempts = readJsonFile(fname)

# %%
fname = 'sgd_attempts_ac4119_202005119b'
all_attempts_new = readJsonFile(fname)

# %%
eval_metrics_df
# Out:
#       elapsed_time  train_set                      dev_set vectorizer  \
# 0        15.489576          0          ac4119_dev_w_tokens      tfidf
# 1        14.665768          0  ac4119_train_set_1_w_tokens      tfidf
# 2        14.387325          0  ac4119_train_set_2_w_tokens      tfidf
# 3        15.065834          0  ac4119_train_set_3_w_tokens      tfidf
# 4        14.234047          0  ac4119_train_set_4_w_tokens      tfidf
# ...            ...        ...                          ...        ...
# 2939     14.133293          7  ac4119_train_set_6_w_tokens      tfidf
# 2940     11.869360          7  ac4119_train_set_6_w_tokens      tfidf
# 2941     12.728566          7  ac4119_train_set_6_w_tokens      tfidf
# 2942     18.423309          7  ac4119_train_set_6_w_tokens      tfidf
# 2943     11.715576          7  ac4119_train_set_6_w_tokens      tfidf
#
#               model  params.random_state params.class_weight  \
# 0     SGDClassifier                  519            balanced
# 1     SGDClassifier                  519            balanced
# 2     SGDClassifier                  519            balanced
# 3     SGDClassifier                  519            balanced
# 4     SGDClassifier                  519            balanced
# ...             ...                  ...                 ...
# 2939  SGDClassifier                  519            balanced
# 2940  SGDClassifier                  519            balanced
# 2941  SGDClassifier                  519            balanced
# 2942  SGDClassifier                  519            balanced
# 2943  SGDClassifier                  519            balanced
#
#       metrics.train_accuracy  metrics.test_accuracy  metrics.test_auc_pred  \
# 0                   0.703404               0.612451               0.652663
# 1                   0.703404               0.672118               0.679852
# 2                   0.703404               0.670310               0.678182
# 3                   0.703404               0.673258               0.680898
# 4                   0.703404               0.671128               0.679009
# ...                      ...                    ...                    ...
# 2939                0.444442               0.444442               0.500000
# 2940                0.603348               0.601498               0.607448
# 2941                0.724620               0.643543               0.645729
# 2942                0.444442               0.444442               0.500000
# 2943                0.444442               0.444442               0.500000
#
#       metrics.test_auc_score  metrics.test_ap_pred  metrics.test_ap_score  \
# 0                   0.709396              0.147248               0.200120
# 1                   0.743642              0.565550               0.669832
# 2                   0.742235              0.564047               0.666579
# 3                   0.745991              0.566501               0.670143
# 4                   0.743160              0.564750               0.665896
# ...                      ...                   ...                    ...
# 2939                0.500000              0.444442               0.444442
# 2940                0.641411              0.509199               0.565341
# 2941                0.698631              0.539551               0.609903
# 2942                0.500000              0.444442               0.444442
# 2943                0.500000              0.444442               0.444442
#
#       params.alpha    params.loss params.penalty
# 0              NaN            NaN            NaN
# 1              NaN            NaN            NaN
# 2              NaN            NaN            NaN
# 3              NaN            NaN            NaN
# 4              NaN            NaN            NaN
# ...            ...            ...            ...
# 2939          0.01  squared_hinge             l1
# 2940          0.01  squared_hinge     elasticnet
# 2941          0.01     perceptron             l2
# 2942          0.01     perceptron             l1
# 2943          0.01     perceptron     elasticnet
#
# [2944 rows x 16 columns]

# %%
eval_metrics_df = pd.json_normalize(all_attempts)
eval_metrics_df_new = pd.json_normalize(all_attempts_new)
vs_dev_set = eval_metrics_df[eval_metrics_df['dev_set'] == 'ac4119_dev_w_tokens']

# %%
eval_metrics_df = pd.concat([vs_dev_set, eval_metrics_df_new])

# %% [markdown]
# Best Performing Overall

# %%
best_ap_score = max(eval_metrics_df['metrics.test_ap_score'])
best_auc_score = max(eval_metrics_df['metrics.test_auc_score'])

eval_metrics_df[eval_metrics_df['metrics.test_auc_score'] == best_auc_score]
# Out:
#     elapsed_time  train_set dev_set vectorizer model  params.random_state  \
# 24           NaN        NaN     NaN        NaN   NaN                  519
#
#    params.class_weight  metrics.train_accuracy  metrics.test_accuracy  \
# 24            balanced                0.649654               0.549001
#
#     metrics.test_auc_pred  metrics.test_auc_score  metrics.test_ap_pred  \
# 24               0.697221                 0.77029              0.161676
#
#     metrics.test_ap_score  params.alpha     params.loss params.penalty
# 24               0.249991           0.1  modified_huber             l2

# %%
eval_metrics_df[eval_metrics_df['metrics.test_ap_score'] == best_ap_score]
# Out:
#     elapsed_time  train_set dev_set vectorizer model  params.random_state  \
# 24           NaN        NaN     NaN        NaN   NaN                  519
#
#    params.class_weight  metrics.train_accuracy  metrics.test_accuracy  \
# 24            balanced                0.649654               0.549001
#
#     metrics.test_auc_pred  metrics.test_auc_score  metrics.test_ap_pred  \
# 24               0.697221                 0.77029              0.161676
#
#     metrics.test_ap_score  params.alpha     params.loss params.penalty
# 24               0.249991           0.1  modified_huber             l2

# %%
vs_dev_set = eval_metrics_df[eval_metrics_df['dev_set'] == 'ac4119_dev_w_tokens']

# %%
best_ap_score = max(vs_dev_set['metrics.test_ap_score'])
best_auc_score = max(vs_dev_set['metrics.test_auc_score'])

vs_dev_set[vs_dev_set['metrics.test_auc_score'] == best_auc_score]
# Out:
#     elapsed_time  train_set              dev_set vectorizer      model  \
# 98     11.832398          3  ac4119_dev_w_tokens      tfidf  LinearSVC
#
#     params.random_state  params.C    params.loss params.penalty  \
# 98                  519      0.01  squared_hinge             l2
#
#    params.class_weight  metrics.train_accuracy  metrics.test_accuracy  \
# 98            balanced                0.681908               0.631772
#
#     metrics.test_auc_pred  metrics.test_auc_score  metrics.test_ap_pred  \
# 98               0.652231                0.708217               0.14814
#
#     metrics.test_ap_score
# 98               0.202325

# %%
vs_dev_set[vs_dev_set['metrics.test_ap_score'] == best_ap_score]
# Out:
#     elapsed_time  train_set              dev_set vectorizer      model  \
# 98     11.832398          3  ac4119_dev_w_tokens      tfidf  LinearSVC
#
#     params.random_state  params.C    params.loss params.penalty  \
# 98                  519      0.01  squared_hinge             l2
#
#    params.class_weight  metrics.train_accuracy  metrics.test_accuracy  \
# 98            balanced                0.681908               0.631772
#
#     metrics.test_auc_pred  metrics.test_auc_score  metrics.test_ap_pred  \
# 98               0.652231                0.708217               0.14814
#
#     metrics.test_ap_score
# 98               0.202325

# %%
Hey guys, lmk if you guys think you are done with you implementations. One thing I don't think any of us have tried yet, it to incorporate the

# %%
vs_dev_set.sort_values(by=['metrics.test_auc_score'], ascending=False)
# Out:
#      elapsed_time  train_set              dev_set vectorizer      model  \
# 98      11.832398          3  ac4119_dev_w_tokens      tfidf  LinearSVC
# 226     16.606720          7  ac4119_dev_w_tokens      tfidf  LinearSVC
# 34      12.437826          1  ac4119_dev_w_tokens      tfidf  LinearSVC
# 130     12.384853          4  ac4119_dev_w_tokens      tfidf  LinearSVC
# 194     12.922601          6  ac4119_dev_w_tokens      tfidf  LinearSVC
# 2       13.573386          0  ac4119_dev_w_tokens      tfidf  LinearSVC
# 66      12.160653          2  ac4119_dev_w_tokens      tfidf  LinearSVC
# 162      7.625858          5  ac4119_dev_w_tokens      tfidf  LinearSVC
# 100     15.308733          3  ac4119_dev_w_tokens      tfidf  LinearSVC
# 228     15.057238          7  ac4119_dev_w_tokens      tfidf  LinearSVC
# 36      12.028322          1  ac4119_dev_w_tokens      tfidf  LinearSVC
# 4       12.482738          0  ac4119_dev_w_tokens      tfidf  LinearSVC
# 132     11.788006          4  ac4119_dev_w_tokens      tfidf  LinearSVC
# 196     11.820729          6  ac4119_dev_w_tokens      tfidf  LinearSVC
# 97      13.318906          3  ac4119_dev_w_tokens      tfidf  LinearSVC
# 68      12.630987          2  ac4119_dev_w_tokens      tfidf  LinearSVC
# 225     13.368862          7  ac4119_dev_w_tokens      tfidf  LinearSVC
# 33      16.892066          1  ac4119_dev_w_tokens      tfidf  LinearSVC
# 0       13.344661          0  ac4119_dev_w_tokens      tfidf  LinearSVC
# 1       14.467952          0  ac4119_dev_w_tokens      tfidf  LinearSVC
# 164      8.358392          5  ac4119_dev_w_tokens      tfidf  LinearSVC
# 193     11.925542          6  ac4119_dev_w_tokens      tfidf  LinearSVC
# 99      11.855154          3  ac4119_dev_w_tokens      tfidf  LinearSVC
# 129     12.023285          4  ac4119_dev_w_tokens      tfidf  LinearSVC
# 227     14.817772          7  ac4119_dev_w_tokens      tfidf  LinearSVC
# 35      11.798102          1  ac4119_dev_w_tokens      tfidf  LinearSVC
# 3       13.727621          0  ac4119_dev_w_tokens      tfidf  LinearSVC
# 65      11.860189          2  ac4119_dev_w_tokens      tfidf  LinearSVC
# 163      7.720113          5  ac4119_dev_w_tokens      tfidf  LinearSVC
# 161      7.269694          5  ac4119_dev_w_tokens      tfidf  LinearSVC
# 131     12.720435          4  ac4119_dev_w_tokens      tfidf  LinearSVC
# 195     12.002915          6  ac4119_dev_w_tokens      tfidf  LinearSVC
# 67      12.583687          2  ac4119_dev_w_tokens      tfidf  LinearSVC
#
#      params.random_state  params.C    params.loss params.penalty  \
# 98                   519     0.010  squared_hinge             l2
# 226                  519     0.010  squared_hinge             l2
# 34                   519     0.010  squared_hinge             l2
# 130                  519     0.010  squared_hinge             l2
# 194                  519     0.010  squared_hinge             l2
# 2                    519     0.010  squared_hinge             l2
# 66                   519     0.010  squared_hinge             l2
# 162                  519     0.010  squared_hinge             l2
# 100                  519     0.001  squared_hinge             l2
# 228                  519     0.001  squared_hinge             l2
# 36                   519     0.001  squared_hinge             l2
# 4                    519     0.001  squared_hinge             l2
# 132                  519     0.001  squared_hinge             l2
# 196                  519     0.001  squared_hinge             l2
# 97                   519     0.010          hinge             l2
# 68                   519     0.001  squared_hinge             l2
# 225                  519     0.010          hinge             l2
# 33                   519     0.010          hinge             l2
# 0                    519     0.010          hinge             l2
# 1                    519     0.010          hinge             l2
# 164                  519     0.001  squared_hinge             l2
# 193                  519     0.010          hinge             l2
# 99                   519     0.001          hinge             l2
# 129                  519     0.010          hinge             l2
# 227                  519     0.001          hinge             l2
# 35                   519     0.001          hinge             l2
# 3                    519     0.001          hinge             l2
# 65                   519     0.010          hinge             l2
# 163                  519     0.001          hinge             l2
# 161                  519     0.010          hinge             l2
# 131                  519     0.001          hinge             l2
# 195                  519     0.001          hinge             l2
# 67                   519     0.001          hinge             l2
#
#     params.class_weight  metrics.train_accuracy  metrics.test_accuracy  \
# 98             balanced                0.681908               0.631772
# 226            balanced                0.682726               0.631216
# 34             balanced                0.678530               0.633916
# 130            balanced                0.679842               0.634529
# 194            balanced                0.678229               0.635726
# 2              balanced                0.680617               0.634918
# 66             balanced                0.674248               0.629629
# 162            balanced                0.688201               0.634863
# 100            balanced                0.661510               0.625313
# 228            balanced                0.660606               0.625007
# 36             balanced                0.658562               0.628348
# 4              balanced                0.660046               0.628960
# 132            balanced                0.657034               0.628348
# 196            balanced                0.657271               0.628153
# 97             balanced                0.648793               0.578011
# 68             balanced                0.652946               0.624979
# 225            balanced                0.649460               0.580600
# 33             balanced                0.651246               0.607049
# 0              balanced                0.650105               0.584080
# 1              balanced                0.650105               0.584080
# 164            balanced                0.669171               0.638482
# 193            balanced                0.648922               0.585417
# 99             balanced                0.595989               0.870427
# 129            balanced                0.647717               0.584832
# 227            balanced                0.597883               0.870149
# 35             balanced                0.596075               0.870316
# 3              balanced                0.595171               0.869536
# 65             balanced                0.644834               0.578512
# 163            balanced                0.604877               0.868283
# 161            balanced                0.604877               0.868283
# 131            balanced                0.596269               0.870260
# 195            balanced                0.598055               0.869898
# 67             balanced                0.594096               0.870873
#
#      metrics.test_auc_pred  metrics.test_auc_score  metrics.test_ap_pred  \
# 98                0.652231                0.708217              0.148140
# 226               0.651922                0.707805              0.147982
# 34                0.651601                0.706854              0.148008
# 130               0.652671                0.706788              0.148483
# 194               0.651879                0.706696              0.148229
# 2                 0.654104                0.706090              0.149096
# 66                0.648485                0.705006              0.146500
# 162               0.646536                0.698478              0.146005
# 100               0.641707                0.695702              0.143580
# 228               0.641415                0.695440              0.143450
# 36                0.642545                0.695119              0.144063
# 4                 0.643008                0.694585              0.144277
# 132               0.642059                0.694226              0.143871
# 196               0.641586                0.694210              0.143674
# 97                0.641520                0.693310              0.141458
# 68                0.641522                0.693079              0.143490
# 225               0.641866                0.692904              0.141684
# 33                0.642606                0.692637              0.143064
# 0                 0.640156                0.692220              0.141187
# 1                 0.640156                0.692220              0.141187
# 164               0.637609                0.692031              0.142631
# 193               0.640049                0.691914              0.141199
# 99                0.540334                0.691841              0.118874
# 129               0.640210                0.691711              0.141236
# 227               0.540422                0.691533              0.118862
# 35                0.542946                0.691424              0.120407
# 3                 0.539352                0.690940              0.118100
# 65                0.639853                0.690612              0.140865
# 163               0.545584                0.690571              0.121488
# 161               0.545584                0.690571              0.121488
# 131               0.542186                0.690376              0.119936
# 195               0.540039                0.690368              0.118580
# 67                0.537907                0.689316              0.117553
#
#      metrics.test_ap_score
# 98                0.202325
# 226               0.200713
# 34                0.200273
# 130               0.201089
# 194               0.201103
# 2                 0.200419
# 66                0.200419
# 162               0.194541
# 100               0.191973
# 228               0.190967
# 36                0.191158
# 4                 0.190625
# 132               0.190517
# 196               0.191076
# 97                0.190785
# 68                0.189816
# 225               0.189839
# 33                0.189818
# 0                 0.189362
# 1                 0.189362
# 164               0.189014
# 193               0.190085
# 99                0.188527
# 129               0.189089
# 227               0.187794
# 35                0.188066
# 3                 0.187454
# 65                0.188515
# 163               0.187798
# 161               0.187798
# 131               0.187281
# 195               0.187689
# 67                0.186311

# %%
fname = 'l1_attempts_ac4119_20200516'
l1_attempts = readJsonFile(fname)

eval_metrics_df = pd.json_normalize(l1_attempts)
vs_dev_set = eval_metrics_df[eval_metrics_df['dev_set'] == 'ac4119_dev_w_tokens']

best_ap_score = max(vs_dev_set['metrics.test_ap_score'])
best_auc_score = max(vs_dev_set['metrics.test_auc_score'])

vs_dev_set[vs_dev_set['metrics.test_auc_score'] == best_auc_score]
# Out:
#     elapsed_time  train_set              dev_set vectorizer      model  \
# 16     15.444977          1  ac4119_dev_w_tokens      tfidf  LinearSVC
#
#     params.random_state  params.C    params.loss params.penalty  params.dual  \
# 16                  519      0.01  squared_hinge             l1        False
#
#    params.class_weight  metrics.train_accuracy  metrics.test_accuracy  \
# 16            balanced                0.582196               0.500167
#
#     metrics.test_auc_pred  metrics.test_auc_score  metrics.test_ap_pred  \
# 16               0.591268                0.622327              0.123265
#
#     metrics.test_ap_score
# 16               0.145876

# %%
fname = 'sgd_attempts_ac4119_202005117'
l1_attempts = readJsonFile(fname)

eval_metrics_df = pd.json_normalize(l1_attempts)
vs_dev_set = eval_metrics_df[eval_metrics_df['dev_set'] == 'ac4119_dev_w_tokens']

best_ap_score = max(vs_dev_set['metrics.test_ap_score'])
best_auc_score = max(vs_dev_set['metrics.test_auc_score'])

vs_dev_set[vs_dev_set['metrics.test_auc_score'] == best_auc_score]
# Out:
#       elapsed_time  train_set              dev_set vectorizer          model  \
# 1147      9.986314          3  ac4119_dev_w_tokens      tfidf  SGDClassifier
#
#       params.random_state params.class_weight  metrics.train_accuracy  \
# 1147                  519            balanced                0.696239
#
#       metrics.test_accuracy  metrics.test_auc_pred  metrics.test_auc_score  \
# 1147               0.637925               0.657601                0.713023
#
#       metrics.test_ap_pred  metrics.test_ap_score  params.alpha params.loss  \
# 1147              0.150735               0.204783        0.0001         log
#
#      params.penalty
# 1147             l2

# %%
best_auc_score = max(eval_metrics_df['metrics.test_auc_score'])
eval_metrics_df[eval_metrics_df['metrics.test_auc_score'] == best_auc_score]
# Out:
#      elapsed_time  train_set                      dev_set vectorizer  \
# 745      13.02766          1  ac4119_train_set_7_w_tokens      tfidf
#
#              model  params.random_state params.class_weight  \
# 745  SGDClassifier                  519            balanced
#
#      metrics.train_accuracy  metrics.test_accuracy  metrics.test_auc_pred  \
# 745                0.751452               0.700155               0.704557
#
#      metrics.test_auc_score  metrics.test_ap_pred  metrics.test_ap_score  \
# 745                0.770423              0.589877               0.692766
#
#      params.alpha     params.loss params.penalty
# 745        0.0001  modified_huber             l2

# %%
vs_dev_set.sort_values(by=['metrics.test_auc_score'], ascending=False).head(100)
# Out:
#       elapsed_time  train_set              dev_set vectorizer          model  \
# 1147      9.986314          3  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 1168     10.090332          3  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 1165     10.063156          3  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 1144      9.977308          3  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 24       14.842904          3  ac4119_dev_w_tokens      tfidf  SGDClassifier
# ...            ...        ...                  ...        ...            ...
# 802      11.264472          2  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 439       9.819935          1  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 2231     45.800240          6  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 447      10.064121          1  ac4119_dev_w_tokens      tfidf  SGDClassifier
# 1519     55.302111          4  ac4119_dev_w_tokens      tfidf  SGDClassifier
#
#       params.random_state params.class_weight  metrics.train_accuracy  \
# 1147                  519            balanced                0.696239
# 1168                  519            balanced                0.693657
# 1165                  519            balanced                0.693614
# 1144                  519            balanced                0.703920
# 24                    519            balanced                0.703920
# ...                   ...                 ...                     ...
# 802                   519            balanced                0.658476
# 439                   519            balanced                0.644296
# 2231                  519            balanced                0.688299
# 447                   519            balanced                0.662822
# 1519                  519            balanced                0.648814
#
#       metrics.test_accuracy  metrics.test_auc_pred  metrics.test_auc_score  \
# 1147               0.637925               0.657601                0.713023
# 1168               0.633137               0.657610                0.712482
# 1165               0.633109               0.657473                0.712478
# 1144               0.618993               0.658127                0.712472
# 24                 0.618993               0.658127                0.712472
# ...                     ...                    ...                     ...
# 802                0.623531               0.645578                0.697171
# 439                0.554068               0.643147                0.697028
# 2231               0.615068               0.645123                0.696981
# 447                0.632524               0.644505                0.696873
# 1519               0.563200               0.643488                0.696843
#
#       metrics.test_ap_pred  metrics.test_ap_score  params.alpha  \
# 1147              0.150735               0.204783        0.0001
# 1168              0.150436               0.204655        0.0010
# 1165              0.150378               0.204665        0.0010
# 1144              0.149802               0.201984        0.0001
# 24                0.149802               0.201984           NaN
# ...                    ...                    ...           ...
# 802               0.145015               0.193580        0.0010
# 439               0.141190               0.194326        0.0010
# 2231              0.144412               0.188686        0.0001
# 447               0.145061               0.195586        0.0010
# 1519              0.141632               0.194068        0.0010
#
#          params.loss params.penalty
# 1147             log             l2
# 1168   squared_hinge             l2
# 1165  modified_huber             l2
# 1144           hinge             l2
# 24               NaN            NaN
# ...              ...            ...
# 802              log             l2
# 439            hinge             l2
# 2231  modified_huber             l1
# 447   modified_huber     elasticnet
# 1519           hinge             l2
#
# [100 rows x 16 columns]

# %%
l1_attempts[1147]
# Out:
# {'dev_set': 'ac4119_dev_w_tokens',
#  'elapsed_time': 9.986313823144883,
#  'metrics': {'test_accuracy': 0.6379252742357592,
#   'test_ap_pred': 0.15073490969988293,
#   'test_ap_score': 0.20478308908951437,
#   'test_auc_pred': 0.6576007450160107,
#   'test_auc_score': 0.7130227871060515,
#   'train_accuracy': 0.696238757154538},
#  'model': 'SGDClassifier',
#  'params': {'alpha': 0.0001,
#   'class_weight': 'balanced',
#   'loss': 'log',
#   'penalty': 'l2',
#   'random_state': 519},
#  'train_set': 3,
#  'vectorizer': 'tfidf'}

# %%
all_attempts = [{"params": {"n_neighbors": 10}, "metrics": {"train_accuracy": 0.873087685451661, "test_accuracy": 0.8415279247174119, "test_auc_pred": 0.511729185694714, "test_auc_score": 0.5310443356900929, "test_ap_pred": 0.10429276470132186, "test_ap_score": 0.11094622963614453}}, {"params": {"n_neighbors": 11}, "metrics": {"train_accuracy": 0.8520093752242162, "test_accuracy": 0.8107355643409989, "test_auc_pred": 0.5110040896710323, "test_auc_score": 0.5303059115386078, "test_ap_pred": 0.10391791154049448, "test_ap_score": 0.11035856176038553}}, {"params": {"n_neighbors": 13}, "metrics": {"train_accuracy": 0.8543810837312754, "test_accuracy": 0.8203964586001448, "test_auc_pred": 0.5106669449518589, "test_auc_score": 0.5321886561237693, "test_ap_pred": 0.10387427935448956, "test_ap_score": 0.11096606083238872}}, {"params": {"n_neighbors": 14}, "metrics": {"train_accuracy": 0.8718958521010547, "test_accuracy": 0.8494626649590734, "test_auc_pred": 0.509094157913765, "test_auc_score": 0.5305561303611523, "test_ap_pred": 0.10363763504514066, "test_ap_score": 0.11034996607735038}}, {"params": {"n_neighbors": 15}, "metrics": {"train_accuracy": 0.8562545341486164, "test_accuracy": 0.8282476752603152, "test_auc_pred": 0.5098089414153606, "test_auc_score": 0.5308391938020214, "test_ap_pred": 0.10369562558104857, "test_ap_score": 0.11053444304133936}}, {"params": {"n_neighbors": 20}, "metrics": {"train_accuracy": 0.8732630722992418, "test_accuracy": 0.858037752658834, "test_auc_pred": 0.505478259776339, "test_auc_score": 0.5333016482366436, "test_ap_pred": 0.10274942473584053, "test_ap_score": 0.11007725822596078}}, {"params": {"n_neighbors": 5}, "metrics": {"train_accuracy": 0.8522286087836922, "test_accuracy": 0.7633776936355031, "test_auc_pred": 0.5149185582584443, "test_auc_score": 0.5241492296698905, "test_ap_pred": 0.10470122635315257, "test_ap_score": 0.10815341284068077}}]

# %%
eval_metrics_df = pd.json_normalize(all_attempts)

# %%
eval_metrics_df
# Out:
#    params.n_neighbors  metrics.train_accuracy  metrics.test_accuracy  \
# 0                  10                0.873088               0.841528
# 1                  11                0.852009               0.810736
# 2                  13                0.854381               0.820396
# 3                  14                0.871896               0.849463
# 4                  15                0.856255               0.828248
# 5                  20                0.873263               0.858038
# 6                   5                0.852229               0.763378
#
#    metrics.test_auc_pred  metrics.test_auc_score  metrics.test_ap_pred  \
# 0               0.511729                0.531044              0.104293
# 1               0.511004                0.530306              0.103918
# 2               0.510667                0.532189              0.103874
# 3               0.509094                0.530556              0.103638
# 4               0.509809                0.530839              0.103696
# 5               0.505478                0.533302              0.102749
# 6               0.514919                0.524149              0.104701
#
#    metrics.test_ap_score
# 0               0.110946
# 1               0.110359
# 2               0.110966
# 3               0.110350
# 4               0.110534
# 5               0.110077
# 6               0.108153
