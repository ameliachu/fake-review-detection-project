# %%
import ast

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import accuracy_score, roc_auc_score, average_precision_score

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#taken from Amelia!

def ClassifierMetrics (X_train, Y_train, X_test, Y_test, fitted_model):
    """
    X_train: training set features
    Y_train: training set labels
    X_test: dev/test set features
    Y_test: dev/test set labels
    fitted_model: 
    """
    Y_pred = fitted_model.predict(X_test)
    # If your classifier doesn't output decision_function, use predict_proba. 
    # Make sure it is taking the prob of the '1' class
    Y_score = fitted_model.predict_proba(X_test)[:,1]
    metrics = {'train_accuracy': fitted_model.score(X_train, Y_train),
               'test_accuracy': fitted_model.score(X_test, Y_test),
               'test_auc_pred': roc_auc_score(Y_test, Y_pred),
               'test_auc_score': roc_auc_score(Y_test, Y_score),
               'test_ap_pred': average_precision_score(Y_test, Y_pred),
               'test_ap_score': average_precision_score(Y_test, Y_score)}
    return metrics

# %% [markdown]
# ## Loading Data

# %%
fake=pd.read_csv('fake_tokens.csv')
fake=fake.rename(columns={'Unnamed: 0':'index'})
real=pd.read_csv('real_tokens.csv')
real=real.rename(columns={'Unnamed: 0':'index'})
valid=pd.read_csv('valid_tokens.csv')

# %%
real['filtered_tokens']=real['filtered_tokens'].apply(lambda x: ast.literal_eval(x))
real['filtered_tokens']=real['filtered_tokens'].apply(lambda x: ' '.join(x).split())

fake['filtered_tokens']=fake['filtered_tokens'].apply(lambda x: ast.literal_eval(x))
fake['filtered_tokens']=fake['filtered_tokens'].apply(lambda x: ' '.join(x).split())

valid['filtered_tokens']=valid['filtered_tokens'].apply(lambda x: ast.literal_eval(x))
valid['filtered_tokens']=valid['filtered_tokens'].apply(lambda x: ' '.join(x).split())

val_x=valid.drop(['label'],axis=1)
val_y=valid['label']

# %%
full_df=real.append(fake,sort=False)
x=full_df.drop(['label'],axis=1)
y=full_df['label']

# %%
full_df
# Out:
#         index   ex_id  user_id  prod_id  rating  label        date  \
# 0          11      15      938        0     5.0      0  2014-10-10
# 1          12      16      939        0     3.0      0  2014-10-03
# 2          13      18      941        0     5.0      0  2014-08-10
# 3          14      19      942        0     4.0      0  2014-06-17
# 4          15      21      944        0     4.0      0  2014-05-21
# 5          16      26      949        0     4.0      0  2014-03-01
# 6          17      27      950        0     4.0      0  2014-01-24
# 7          18      28      951        0     5.0      0  2014-01-18
# 8          19      29      952        0     5.0      0  2014-01-16
# 9          20      32      955        0     2.0      0  2013-09-10
# 10         21      35      958        0     4.0      0  2013-06-23
# 11         22      36      959        0     4.0      0  2013-04-30
# 12         23      37      960        0     4.0      0  2013-04-16
# 13         24      38      961        0     5.0      0  2013-04-10
# 14         25      39      962        0     2.0      0  2013-03-25
# 15         26      40      963        0     5.0      0  2013-03-02
# 16         27      41      964        0     4.0      0  2013-02-20
# 17         28      42      965        0     4.0      0  2013-02-14
# 18         29      44      967        0     4.0      0  2012-12-15
# 19         30      45      968        0     4.0      0  2012-11-16
# 20         31      47      970        0     4.0      0  2012-10-07
# 21         32      48      971        0     4.0      0  2012-09-16
# 22         33      49      972        0     1.0      0  2012-08-12
# 23         34      50      973        0     3.0      0  2012-08-03
# 24         35      51      974        0     4.0      0  2012-07-25
# 25         36      52      975        0     2.0      0  2012-06-29
# 26         37      55      978        0     2.0      0  2012-04-30
# 27         38      57      980        0     5.0      0  2012-03-30
# 28         39      59      982        0     3.0      0  2012-03-05
# 29         40      60      983        0     4.0      0  2012-02-22
# ...       ...     ...      ...      ...     ...    ...         ...
# 25789  250457  358376   160952      920     5.0      1  2013-01-08
# 25790  250458  358377    14406      920     5.0      1  2012-12-13
# 25791  250459  358378   160953      920     5.0      1  2012-11-17
# 25792  250655  358657   161020      921     2.0      1  2014-11-16
# 25793  250656  358658   161021      921     2.0      1  2012-11-25
# 25794  250657  358659   161022      921     4.0      1  2014-10-31
# 25795  250658  358660   161023      921     4.0      1  2014-10-19
# 25796  250659  358663   161025      921     5.0      1  2014-12-13
# 25797  250660  358664   161026      921     5.0      1  2014-12-11
# 25798  250661  358665   161027      921     5.0      1  2014-12-02
# 25799  250662  358666   161028      921     5.0      1  2014-10-30
# 25800  250663  358668   161030      921     5.0      1  2014-09-22
# 25801  250664  358669   161031      921     5.0      1  2014-09-21
# 25802  250665  358670   161032      921     5.0      1  2014-08-14
# 25803  250666  358671   161033      921     5.0      1  2014-08-12
# 25804  250667  358672    98465      921     5.0      1  2014-08-09
# 25805  250668  358673   161034      921     5.0      1  2014-07-29
# 25806  250669  358676   161036      921     5.0      1  2014-05-20
# 25807  250670  358677   161037      921     5.0      1  2014-05-16
# 25808  250671  358678   161038      921     5.0      1  2014-05-15
# 25809  250672  358679    99699      921     5.0      1  2014-05-03
# 25810  250673  358680   161039      921     5.0      1  2014-03-06
# 25811  250674  358681   161040      921     5.0      1  2013-07-31
# 25812  250675  358682   161041      921     5.0      1  2013-05-01
# 25813  250676  358683    77482      921     5.0      1  2013-04-26
# 25814  250677  358685   161043      921     5.0      1  2012-07-31
# 25815  250678  358686   161044      921     5.0      1  2012-06-12
# 25816  250679  358688   161046      921     5.0      1  2011-12-01
# 25817  250680  358689   161047      921     5.0      1  2011-11-15
# 25818  250793  358849   161111      349     1.0      1  2014-03-25
#
#                                                   review  \
# 0      I had the braised lamb sandwich and was one of...
# 1      This spot is close to my job so I decided to c...
# 2      Needed a quick, healthy light "lunch" and this...
# 3      Their artichoke chicken salad is good and plenty.
# 4      Needed a quick bite and stopped here because o...
# 5      Quick, delicious and filling. After a few hour...
# 6      Delicious, consistent, well-priced. Food taste...
# 7      Really quaint little "hole in the wall" kind o...
# 8                                Delicious lamb sandwich
# 9      Been meaning to try this place for a while-hig...
# 10     The taramosalata is to die for.  I recommend t...
# 11     What a pleasant little shop. Tiny, cute, liquo...
# 12     This place is TINY! I think it fits 10 people ...
# 13                     Lamb sandwich... mmm... eat here.
# 14     I ordered the spinach pies. Not very good. Sog...
# 15     This tiny cafe on Thompson has been a favorite...
# 16     I was impressed! This was my first time pickin...
# 17     Ohhh Snack. I love you, Snack. I order from he...
# 18     Perfect for what the name implies: great butte...
# 19     Really delicious sandwich- had the lamb. It wa...
# 20     Delicious, savory, creamy--try the pastitsio, ...
# 21     Super small but it felt cozy rather than cramp...
# 22     Lacklustre service, soggy lukewarm spinach pie...
# 23     I am Greek, and a huge fan of Greek food, so a...
# 24     A friend recommended I try Snack - was really ...
# 25     Followed the great Yelp reviews to grab a sand...
# 26     Stopped in for lunch takeout during work.  I a...
# 27     I was trying to wait until after my headrush d...
# 28     Nice little Greek restaurant that serves authe...
# 29     a whole in the wall, but get there outside reg...
# ...                                                  ...
# 25789  Like many other BBQ lovers who have traveled t...
# 25790  As I took my first bite I giggled like a littl...
# 25791  Unbelievable. I've been following Daniel Delan...
# 25792  This place manages to mess up dishes that are ...
# 25793  I used to really enjoy the place for the relax...
# 25794  Bijan's is a beautiful surprise, if you're new...
# 25795  Hell yeah! Great intimate rustic ambiance. Del...
# 25796  Great local bar with a cozy atmosphere (firepl...
# 25797  This cozy Brooklyn restaurant is for sure a wi...
# 25798  I wanna let you in on one of Brooklyn's best k...
# 25799  BIJANS is the BEST!!! I love it here. First le...
# 25800  Great neighbourhood bar where you immediately ...
# 25801  My friend and I were visiting Brooklyn and dec...
# 25802  I really enjoyed this place, the persian wings...
# 25803  I recently found myself hanging in Brooklyn fo...
# 25804  This is my favorite go-to spot in the neighbor...
# 25805  Everything was delightful. Perfect atmosphere,...
# 25806  While waiting at bar to get a table I encounte...
# 25807  Food was great. Service was amazing. Our serve...
# 25808           great food, good drinks, wonderful time.
# 25809  So... Ive tried to write many reviews of this ...
# 25810  Deliciousness- chicken wings and pulled pork s...
# 25811  Delicious meal in a great atmosphere on a cute...
# 25812  Whenever I have a friend in town, we visit Bij...
# 25813  The bartender was  very sweet and funny, as   ...
# 25814  This place is amazing, I loved it so much that...
# 25815  I love this place. Drinks are great, atmospher...
# 25816  Bijan is the best bar I have been to in Brookl...
# 25817  Great local lounge spot! After work and regula...
# 25818  First and last time we try this place.  Pizza ...
#
#                                                   tokens  \
# 0      ['I', 'had', 'the', 'braised', 'lamb', 'sandwi...
# 1      ['This', 'spot', 'is', 'close', 'to', 'my', 'j...
# 2      ['Needed', 'a', 'quick', ',', 'healthy', 'ligh...
# 3      ['Their', 'artichoke', 'chicken', 'salad', 'is...
# 4      ['Needed', 'a', 'quick', 'bite', 'and', 'stopp...
# 5      ['Quick', ',', 'delicious', 'and', 'filling', ...
# 6      ['Delicious', ',', 'consistent', ',', 'well-pr...
# 7      ['Really', 'quaint', 'little', '``', 'hole', '...
# 8                      ['Delicious', 'lamb', 'sandwich']
# 9      ['Been', 'meaning', 'to', 'try', 'this', 'plac...
# 10     ['The', 'taramosalata', 'is', 'to', 'die', 'fo...
# 11     ['What', 'a', 'pleasant', 'little', 'shop', '....
# 12     ['This', 'place', 'is', 'TINY', '!', 'I', 'thi...
# 13     ['Lamb', 'sandwich', '...', 'mmm', '...', 'eat...
# 14     ['I', 'ordered', 'the', 'spinach', 'pies', '.'...
# 15     ['This', 'tiny', 'cafe', 'on', 'Thompson', 'ha...
# 16     ['I', 'was', 'impressed', '!', 'This', 'was', ...
# 17     ['Ohhh', 'Snack', '.', 'I', 'love', 'you', ','...
# 18     ['Perfect', 'for', 'what', 'the', 'name', 'imp...
# 19     ['Really', 'delicious', 'sandwich-', 'had', 't...
# 20     ['Delicious', ',', 'savory', ',', 'creamy', '-...
# 21     ['Super', 'small', 'but', 'it', 'felt', 'cozy'...
# 22     ['Lacklustre', 'service', ',', 'soggy', 'lukew...
# 23     ['I', 'am', 'Greek', ',', 'and', 'a', 'huge', ...
# 24     ['A', 'friend', 'recommended', 'I', 'try', 'Sn...
# 25     ['Followed', 'the', 'great', 'Yelp', 'reviews'...
# 26     ['Stopped', 'in', 'for', 'lunch', 'takeout', '...
# 27     ['I', 'was', 'trying', 'to', 'wait', 'until', ...
# 28     ['Nice', 'little', 'Greek', 'restaurant', 'tha...
# 29     ['a', 'whole', 'in', 'the', 'wall', ',', 'but'...
# ...                                                  ...
# 25789  ['Like', 'many', 'other', 'BBQ', 'lovers', 'wh...
# 25790  ['As', 'I', 'took', 'my', 'first', 'bite', 'I'...
# 25791  ['Unbelievable', '.', 'I', "'ve", 'been', 'fol...
# 25792  ['This', 'place', 'manages', 'to', 'mess', 'up...
# 25793  ['I', 'used', 'to', 'really', 'enjoy', 'the', ...
# 25794  ['Bijan', "'s", 'is', 'a', 'beautiful', 'surpr...
# 25795  ['Hell', 'yeah', '!', 'Great', 'intimate', 'ru...
# 25796  ['Great', 'local', 'bar', 'with', 'a', 'cozy',...
# 25797  ['This', 'cozy', 'Brooklyn', 'restaurant', 'is...
# 25798  ['I', 'wan', 'na', 'let', 'you', 'in', 'on', '...
# 25799  ['BIJANS', 'is', 'the', 'BEST', '!', '!', '!',...
# 25800  ['Great', 'neighbourhood', 'bar', 'where', 'yo...
# 25801  ['My', 'friend', 'and', 'I', 'were', 'visiting...
# 25802  ['I', 'really', 'enjoyed', 'this', 'place', ',...
# 25803  ['I', 'recently', 'found', 'myself', 'hanging'...
# 25804  ['This', 'is', 'my', 'favorite', 'go-to', 'spo...
# 25805  ['Everything', 'was', 'delightful', '.', 'Perf...
# 25806  ['While', 'waiting', 'at', 'bar', 'to', 'get',...
# 25807  ['Food', 'was', 'great', '.', 'Service', 'was'...
# 25808  ['great', 'food', ',', 'good', 'drinks', ',', ...
# 25809  ['So', '...', 'Ive', 'tried', 'to', 'write', '...
# 25810  ['Deliciousness-', 'chicken', 'wings', 'and', ...
# 25811  ['Delicious', 'meal', 'in', 'a', 'great', 'atm...
# 25812  ['Whenever', 'I', 'have', 'a', 'friend', 'in',...
# 25813  ['The', 'bartender', 'was', 'very', 'sweet', '...
# 25814  ['This', 'place', 'is', 'amazing', ',', 'I', '...
# 25815  ['I', 'love', 'this', 'place', '.', 'Drinks', ...
# 25816  ['Bijan', 'is', 'the', 'best', 'bar', 'I', 'ha...
# 25817  ['Great', 'local', 'lounge', 'spot', '!', 'Aft...
# 25818  ['First', 'and', 'last', 'time', 'we', 'try', ...
#
#                                          filtered_tokens
# 0      [braised, lamb, sandwich, best, sandwiches, li...
# 1      [spot, close, job, decided, check, lunch, pric...
# 2      [needed, quick, healthy, light, lunch, place, ...
# 3              [artichoke, chicken, salad, good, plenty]
# 4      [needed, quick, bite, stopped, reviews, really...
# 5      [quick, delicious, filling, hours, shopping, s...
# 6      [delicious, consistent, wellpriced, food, tast...
# 7      [really, quaint, little, hole, wall, kind, sto...
# 8                            [delicious, lamb, sandwich]
# 9      [meaning, try, place, whilehighly, recommended...
# 10     [taramosalata, recommend, shrimp, santorini, g...
# 11     [pleasant, little, shop, tiny, cute, liquor, l...
# 12     [place, tiny, think, fits, 10, people, max, ke...
# 13                            [lamb, sandwich, mmm, eat]
# 14     [ordered, spinach, pies, good, soggy, real, ta...
# 15     [tiny, cafe, thompson, favorite, years, tell, ...
# 16     [impressed, first, time, picking, food, snack,...
# 17     [ohhh, snack, love, snack, order, often, since...
# 18     [perfect, implies, great, butter, bean, salad,...
# 19     [really, delicious, sandwich, lamb, enormous, ...
# 20     [delicious, savory, creamy, try, pastitsio, ve...
# 21     [super, small, felt, cozy, rather, cramped, ge...
# 22     [lacklustre, service, soggy, lukewarm, spinach...
# 23     [greek, huge, fan, greek, food, bit, tough, cr...
# 24     [friend, recommended, try, snack, really, surp...
# 25     [followed, great, yelp, reviews, grab, sandwic...
# 26     [stopped, lunch, takeout, work, asked, server,...
# 27     [trying, wait, headrush, died, posting, hour, ...
# 28     [nice, little, greek, restaurant, serves, auth...
# 29     [whole, wall, get, outside, regular, lunch, ho...
# ...                                                  ...
# 25789  [like, many, bbq, lovers, traveled, throughout...
# 25790  [took, first, bite, giggled, like, little, kid...
# 25791  [unbelievable, following, daniel, delaney, imp...
# 25792  [place, manages, mess, dishes, delicious, ever...
# 25793  [used, really, enjoy, place, relaxed, vibe, go...
# 25794  [bijan, beautiful, surprise, new, neighborhood...
# 25795  [hell, yeah, great, intimate, rustic, ambiance...
# 25796  [great, local, bar, cozy, atmosphere, fireplac...
# 25797  [cozy, brooklyn, restaurant, sure, win, matter...
# 25798  [wan, let, brooklyn, best, kept, secrets, resi...
# 25799  [bijans, best, love, first, let, say, drinks, ...
# 25800  [great, neighbourhood, bar, immediately, feel,...
# 25801  [friend, visiting, brooklyn, decided, stop, re...
# 25802  [really, enjoyed, place, persian, wings, spice...
# 25803  [recently, found, hanging, brooklyn, day, frie...
# 25804  [favorite, goto, spot, neighborhood, happy, ho...
# 25805  [everything, delightful, perfect, atmosphere, ...
# 25806  [waiting, bar, get, table, encountered, possib...
# 25807  [food, great, service, amazing, server, henry,...
# 25808       [great, food, good, drinks, wonderful, time]
# 25809  [ive, tried, write, many, reviews, place, maki...
# 25810  [deliciousness, chicken, wings, pulled, pork, ...
# 25811  [delicious, meal, great, atmosphere, cute, str...
# 25812  [whenever, friend, town, visit, bijan, 2for1, ...
# 25813  [bartender, sweet, funny, waitress, helping, o...
# 25814  [place, amazing, loved, much, back, many, time...
# 25815  [love, place, drinks, great, atmosphere, uniqu...
# 25816  [bijan, best, bar, brooklyn, far, joke, someth...
# 25817  [great, local, lounge, spot, work, regular, ni...
# 25818  [first, last, time, try, place, pizza, crust, ...
#
# [250874 rows x 10 columns]

# %%
num_reviews_user=full_df[['user_id','index']]
num_reviews_user=num_reviews_user.groupby('user_id').count()
num_reviews_user=num_reviews_user.reset_index()
num_reviews_user=num_reviews_user.rename(columns={'index':'train_num_reviews_u'})
num_reviews_user2=val_x[['user_id','review']]
num_reviews_user2=num_reviews_user2.groupby('user_id').count()
num_reviews_user2=num_reviews_user2.reset_index()
num_reviews_user2=num_reviews_user2.rename(columns={'review':'val_num_reviews_u'})

# %%
reviews_user = pd.merge(num_reviews_user, num_reviews_user2, on='user_id', how='outer')
reviews_user['val_num_reviews_u']=reviews_user['val_num_reviews_u'].fillna(0)
reviews_user['train_num_reviews_u']=reviews_user['train_num_reviews_u'].fillna(0)
reviews_user['cumul_num_reviews_u']=reviews_user['train_num_reviews_u']+reviews_user['val_num_reviews_u']

# %%
num_reviews_prod=full_df[['prod_id','index']]
num_reviews_prod=num_reviews_prod.groupby('prod_id').count()
num_reviews_prod=num_reviews_prod.reset_index()
num_reviews_prod=num_reviews_prod.rename(columns={'index':'train_num_reviews_p'})
num_reviews_prod2=val_x[['prod_id','review']]
num_reviews_prod2=num_reviews_prod2.groupby('prod_id').count()
num_reviews_prod2=num_reviews_prod2.reset_index()
num_reviews_prod2=num_reviews_prod2.rename(columns={'review':'val_num_reviews_p'})

# %%
reviews_prod = pd.merge(num_reviews_prod, num_reviews_prod2, on='prod_id', how='outer')
reviews_prod['val_num_reviews_p']=reviews_prod['val_num_reviews_p'].fillna(0)
reviews_prod['train_num_reviews_p']=reviews_prod['train_num_reviews_p'].fillna(0)
reviews_prod['cumul_num_reviews_p']=reviews_prod['train_num_reviews_p']+reviews_prod['val_num_reviews_p']

# %%
reviews_user_train=reviews_user[['user_id','train_num_reviews_u']]
reviews_prod_train=reviews_prod[['prod_id','train_num_reviews_p']]

reviews_user_val=reviews_user[['user_id','cumul_num_reviews_u']]
reviews_prod_val=reviews_prod[['prod_id','cumul_num_reviews_p']]

# %%
train = pd.merge(full_df, reviews_user_train, on='user_id', how='left')
train = pd.merge(train, reviews_prod_train, on='prod_id', how='left')

val = pd.merge(valid, reviews_user_val , on='user_id', how='left')
val = pd.merge(val, reviews_prod_val , on='prod_id', how='left')

# %%
#random undersampling
train_0=train[train['label']==0]
train_1=train[train['label']==1]
train_0= train_0.sample(len(train_1))
train = pd.concat([train_0, train_1], axis=0)

# %%
train=train.rename(columns={'train_num_reviews_u':'num_reviews_u','train_num_reviews_p':'num_reviews_p'})
val=val.rename(columns={'cumul_num_reviews_u':'num_reviews_u','cumul_num_reviews_p':'num_reviews_p'})

# %%
val['filtered_tokens']=val['filtered_tokens'].apply(lambda x: " ".join(i for i in x))
train['filtered_tokens']=train['filtered_tokens'].apply(lambda x: " ".join(i for i in x))

# %%
val['filtered_tokens'][0]
# Out:
# ['around',
#  'good',
#  'place',
#  'cozy',
#  'came',
#  'nt',
#  'huge',
#  'appetite',
#  'stuck',
#  'appetizers',
#  'friend',
#  'combo',
#  'platter',
#  'full']

# %%
feature_cols = ['rating', 'filtered_tokens', 'num_reviews_u', 'num_reviews_p']
train_x=train[feature_cols]
train_y=train['label']
val_x=val[feature_cols]
val_y=val['label']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import make_column_transformer

bow_vectorizer = CountVectorizer(stop_words='english', binary=True)


params = {'max_depth':20,'n_estimators': 100,
  'min_samples_split':0.056, 
  'random_state': 519}

# %%
pipeline = Pipeline([
    ('transformer',  make_column_transformer((StandardScaler(), ['num_reviews_u', 'num_reviews_p']),
                                            (bow_vectorizer, 'filtered_tokens'),
                                            remainder = 'passthrough')),
    ('fitted_randomforest', RandomForestClassifier(**params)),
])

fitted_model = pipeline.fit(train_x, train_y)

# %%
metrics = ClassifierMetrics(train_x, train_y, val_x, val_y, fitted_model)

# %%
metrics
# Out:
# {'train_accuracy': 0.6749486812037647,
#  'test_accuracy': 0.635419566791024,
#  'test_auc_pred': 0.6650806619314011,
#  'test_auc_score': 0.7228826412900473,
#  'test_ap_pred': 0.15372049580975386,
#  'test_ap_score': 0.21893688958109522}
